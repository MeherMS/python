# %% [markdown]
# <h1>Segmenting and Clustering Neighborhoods in Toronto</h1>
# <h3>import libreries</h3>

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# <h3>scrap data and convert them to text </h3>

# %%
r  = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")
data = r.text
soup = BeautifulSoup(data)

# %% [markdown]
# <h3>get the table from the page scraped</h3>

# %%
table=soup.table
row_length = len(table.find_all('tr'))

# %% [markdown]
# <h3>get data from text  table to list </h3>

# %%
data = [ [ 0 for i in range(3) ] for j in range(row_length) ] 
for i in range (1,row_length):
    data[i][0]=table.find_all('tr')[i].find_all('td')[0].getText()
    data[i][1]=table.find_all('tr')[i].find_all('td')[1].getText().rstrip('\n')
    data[i][2]=table.find_all('tr')[i].find_all('td')[2].getText().rstrip('\n')

# %% [markdown]
# <h3>convert the list to dataFrame</h3>

# %%
df = pd.DataFrame(data, columns = ['PostCode', 'Borough','Neighbourhood']) 
df.drop(0)
# Out:
#     PostCode           Borough  \
# 1        M1A      Not assigned
# 2        M2A      Not assigned
# 3        M3A        North York
# 4        M4A        North York
# 5        M5A  Downtown Toronto
# 6        M5A  Downtown Toronto
# 7        M6A        North York
# 8        M6A        North York
# 9        M7A      Queen's Park
# 10       M8A      Not assigned
# 11       M9A         Etobicoke
# 12       M1B       Scarborough
# 13       M1B       Scarborough
# 14       M2B      Not assigned
# 15       M3B        North York
# 16       M4B         East York
# 17       M4B         East York
# 18       M5B  Downtown Toronto
# 19       M5B  Downtown Toronto
# 20       M6B        North York
# 21       M7B      Not assigned
# 22       M8B      Not assigned
# 23       M9B         Etobicoke
# 24       M9B         Etobicoke
# 25       M9B         Etobicoke
# 26       M9B         Etobicoke
# 27       M9B         Etobicoke
# 28       M1C       Scarborough
# 29       M1C       Scarborough
# 30       M1C       Scarborough
# ..       ...               ...
# 259      M9X      Not assigned
# 260      M1Y      Not assigned
# 261      M2Y      Not assigned
# 262      M3Y      Not assigned
# 263      M4Y  Downtown Toronto
# 264      M5Y      Not assigned
# 265      M6Y      Not assigned
# 266      M7Y      East Toronto
# 267      M8Y         Etobicoke
# 268      M8Y         Etobicoke
# 269      M8Y         Etobicoke
# 270      M8Y         Etobicoke
# 271      M8Y         Etobicoke
# 272      M8Y         Etobicoke
# 273      M8Y         Etobicoke
# 274      M8Y         Etobicoke
# 275      M9Y      Not assigned
# 276      M1Z      Not assigned
# 277      M2Z      Not assigned
# 278      M3Z      Not assigned
# 279      M4Z      Not assigned
# 280      M5Z      Not assigned
# 281      M6Z      Not assigned
# 282      M7Z      Not assigned
# 283      M8Z         Etobicoke
# 284      M8Z         Etobicoke
# 285      M8Z         Etobicoke
# 286      M8Z         Etobicoke
# 287      M8Z         Etobicoke
# 288      M9Z      Not assigned
#
#                                          Neighbourhood
# 1                                         Not assigned
# 2                                         Not assigned
# 3                                            Parkwoods
# 4                                     Victoria Village
# 5                                         Harbourfront
# 6                                          Regent Park
# 7                                     Lawrence Heights
# 8                                       Lawrence Manor
# 9                                         Not assigned
# 10                                        Not assigned
# 11                                    Islington Avenue
# 12                                               Rouge
# 13                                             Malvern
# 14                                        Not assigned
# 15                                     Don Mills North
# 16                                    Woodbine Gardens
# 17                                       Parkview Hill
# 18                                             Ryerson
# 19                                     Garden District
# 20                                           Glencairn
# 21                                        Not assigned
# 22                                        Not assigned
# 23                                          Cloverdale
# 24                                           Islington
# 25                                        Martin Grove
# 26                                    Princess Gardens
# 27                                     West Deane Park
# 28                                      Highland Creek
# 29                                          Rouge Hill
# 30                                          Port Union
# ..                                                 ...
# 259                                       Not assigned
# 260                                       Not assigned
# 261                                       Not assigned
# 262                                       Not assigned
# 263                               Church and Wellesley
# 264                                       Not assigned
# 265                                       Not assigned
# 266  Business Reply Mail Processing Centre 969 Eastern
# 267                                         Humber Bay
# 268                                   King's Mill Park
# 269                           Kingsway Park South East
# 270                                          Mimico NE
# 271                                     Old Mill South
# 272                                 The Queensway East
# 273                              Royal York South East
# 274                                           Sunnylea
# 275                                       Not assigned
# 276                                       Not assigned
# 277                                       Not assigned
# 278                                       Not assigned
# 279                                       Not assigned
# 280                                       Not assigned
# 281                                       Not assigned
# 282                                       Not assigned
# 283                           Kingsway Park South West
# 284                                          Mimico NW
# 285                                 The Queensway West
# 286                              Royal York South West
# 287                                     South of Bloor
# 288                                       Not assigned
#
# [288 rows x 3 columns]

# %% [markdown]
# <h3>Delete Not assigned rows </h3>

# %%
df=df[df.Borough != 'Not assigned']
df
# Out:
#     PostCode           Borough  \
# 0          0                 0
# 3        M3A        North York
# 4        M4A        North York
# 5        M5A  Downtown Toronto
# 6        M5A  Downtown Toronto
# 7        M6A        North York
# 8        M6A        North York
# 9        M7A      Queen's Park
# 11       M9A         Etobicoke
# 12       M1B       Scarborough
# 13       M1B       Scarborough
# 15       M3B        North York
# 16       M4B         East York
# 17       M4B         East York
# 18       M5B  Downtown Toronto
# 19       M5B  Downtown Toronto
# 20       M6B        North York
# 23       M9B         Etobicoke
# 24       M9B         Etobicoke
# 25       M9B         Etobicoke
# 26       M9B         Etobicoke
# 27       M9B         Etobicoke
# 28       M1C       Scarborough
# 29       M1C       Scarborough
# 30       M1C       Scarborough
# 32       M3C        North York
# 33       M3C        North York
# 34       M4C         East York
# 35       M5C  Downtown Toronto
# 36       M6C              York
# ..       ...               ...
# 236      M9V         Etobicoke
# 237      M1W       Scarborough
# 240      M4W  Downtown Toronto
# 241      M5W  Downtown Toronto
# 244      M8W         Etobicoke
# 245      M8W         Etobicoke
# 246      M9W         Etobicoke
# 247      M1X       Scarborough
# 250      M4X  Downtown Toronto
# 251      M4X  Downtown Toronto
# 252      M5X  Downtown Toronto
# 253      M5X  Downtown Toronto
# 256      M8X         Etobicoke
# 257      M8X         Etobicoke
# 258      M8X         Etobicoke
# 263      M4Y  Downtown Toronto
# 266      M7Y      East Toronto
# 267      M8Y         Etobicoke
# 268      M8Y         Etobicoke
# 269      M8Y         Etobicoke
# 270      M8Y         Etobicoke
# 271      M8Y         Etobicoke
# 272      M8Y         Etobicoke
# 273      M8Y         Etobicoke
# 274      M8Y         Etobicoke
# 283      M8Z         Etobicoke
# 284      M8Z         Etobicoke
# 285      M8Z         Etobicoke
# 286      M8Z         Etobicoke
# 287      M8Z         Etobicoke
#
#                                          Neighbourhood
# 0                                                    0
# 3                                            Parkwoods
# 4                                     Victoria Village
# 5                                         Harbourfront
# 6                                          Regent Park
# 7                                     Lawrence Heights
# 8                                       Lawrence Manor
# 9                                         Not assigned
# 11                                    Islington Avenue
# 12                                               Rouge
# 13                                             Malvern
# 15                                     Don Mills North
# 16                                    Woodbine Gardens
# 17                                       Parkview Hill
# 18                                             Ryerson
# 19                                     Garden District
# 20                                           Glencairn
# 23                                          Cloverdale
# 24                                           Islington
# 25                                        Martin Grove
# 26                                    Princess Gardens
# 27                                     West Deane Park
# 28                                      Highland Creek
# 29                                          Rouge Hill
# 30                                          Port Union
# 32                                     Flemingdon Park
# 33                                     Don Mills South
# 34                                    Woodbine Heights
# 35                                      St. James Town
# 36                                  Humewood-Cedarvale
# ..                                                 ...
# 236                                        Thistletown
# 237                                    L'Amoreaux West
# 240                                           Rosedale
# 241                    Stn A PO Boxes 25 The Esplanade
# 244                                          Alderwood
# 245                                        Long Branch
# 246                                          Northwest
# 247                                        Upper Rouge
# 250                                        Cabbagetown
# 251                                     St. James Town
# 252                               First Canadian Place
# 253                                   Underground city
# 256                                       The Kingsway
# 257                                    Montgomery Road
# 258                                     Old Mill North
# 263                               Church and Wellesley
# 266  Business Reply Mail Processing Centre 969 Eastern
# 267                                         Humber Bay
# 268                                   King's Mill Park
# 269                           Kingsway Park South East
# 270                                          Mimico NE
# 271                                     Old Mill South
# 272                                 The Queensway East
# 273                              Royal York South East
# 274                                           Sunnylea
# 283                           Kingsway Park South West
# 284                                          Mimico NW
# 285                                 The Queensway West
# 286                              Royal York South West
# 287                                     South of Bloor
#
# [212 rows x 3 columns]

# %% [markdown]
# <h3>replace not assigned neighborhood by Borough name </h3>

# %%
for i in range (len(df.Neighbourhood)):
    if df.iloc[i,2]=="Not assigned":
        df.iloc[i,2]=df.iloc[i,1]

# %% [markdown]
# <h3>Group post code and combine neighborhood</h3>

# %%
df = df.groupby(['PostCode','Borough'])['Neighbourhood'].apply(lambda x: ', '.join(x.astype(str))).reset_index()

# %%
df
# Out:
#     PostCode           Borough  \
# 0          0                 0
# 1        M1B       Scarborough
# 2        M1C       Scarborough
# 3        M1E       Scarborough
# 4        M1G       Scarborough
# 5        M1H       Scarborough
# 6        M1J       Scarborough
# 7        M1K       Scarborough
# 8        M1L       Scarborough
# 9        M1M       Scarborough
# 10       M1N       Scarborough
# 11       M1P       Scarborough
# 12       M1R       Scarborough
# 13       M1S       Scarborough
# 14       M1T       Scarborough
# 15       M1V       Scarborough
# 16       M1W       Scarborough
# 17       M1X       Scarborough
# 18       M2H        North York
# 19       M2J        North York
# 20       M2K        North York
# 21       M2L        North York
# 22       M2M        North York
# 23       M2N        North York
# 24       M2P        North York
# 25       M2R        North York
# 26       M3A        North York
# 27       M3B        North York
# 28       M3C        North York
# 29       M3H        North York
# ..       ...               ...
# 74       M6C              York
# 75       M6E              York
# 76       M6G  Downtown Toronto
# 77       M6H      West Toronto
# 78       M6J      West Toronto
# 79       M6K      West Toronto
# 80       M6L        North York
# 81       M6M              York
# 82       M6N              York
# 83       M6P      West Toronto
# 84       M6R      West Toronto
# 85       M6S      West Toronto
# 86       M7A      Queen's Park
# 87       M7R       Mississauga
# 88       M7Y      East Toronto
# 89       M8V         Etobicoke
# 90       M8W         Etobicoke
# 91       M8X         Etobicoke
# 92       M8Y         Etobicoke
# 93       M8Z         Etobicoke
# 94       M9A         Etobicoke
# 95       M9B         Etobicoke
# 96       M9C         Etobicoke
# 97       M9L        North York
# 98       M9M        North York
# 99       M9N              York
# 100      M9P         Etobicoke
# 101      M9R         Etobicoke
# 102      M9V         Etobicoke
# 103      M9W         Etobicoke
#
#                                          Neighbourhood
# 0                                                    0
# 1                                       Rouge, Malvern
# 2               Highland Creek, Rouge Hill, Port Union
# 3                    Guildwood, Morningside, West Hill
# 4                                               Woburn
# 5                                            Cedarbrae
# 6                                  Scarborough Village
# 7          East Birchmount Park, Ionview, Kennedy Park
# 8                      Clairlea, Golden Mile, Oakridge
# 9      Cliffcrest, Cliffside, Scarborough Village West
# 10                         Birch Cliff, Cliffside West
# 11   Dorset Park, Scarborough Town Centre, Wexford ...
# 12                                   Maryvale, Wexford
# 13                                           Agincourt
# 14             Clarks Corners, Sullivan, Tam O'Shanter
# 15   Agincourt North, L'Amoreaux East, Milliken, St...
# 16                                     L'Amoreaux West
# 17                                         Upper Rouge
# 18                                   Hillcrest Village
# 19                        Fairview, Henry Farm, Oriole
# 20                                     Bayview Village
# 21                            Silver Hills, York Mills
# 22                             Newtonbrook, Willowdale
# 23                                    Willowdale South
# 24                                     York Mills West
# 25                                     Willowdale West
# 26                                           Parkwoods
# 27                                     Don Mills North
# 28                    Flemingdon Park, Don Mills South
# 29     Bathurst Manor, Downsview North, Wilson Heights
# ..                                                 ...
# 74                                  Humewood-Cedarvale
# 75                                 Caledonia-Fairbanks
# 76                                            Christie
# 77                        Dovercourt Village, Dufferin
# 78                            Little Portugal, Trinity
# 79        Brockton, Exhibition Place, Parkdale Village
# 80                  Downsview, North Park, Upwood Park
# 81      Del Ray, Keelesdale, Mount Dennis, Silverthorn
# 82                       The Junction North, Runnymede
# 83                       High Park, The Junction South
# 84                              Parkdale, Roncesvalles
# 85                                  Runnymede, Swansea
# 86                                        Queen's Park
# 87               Canada Post Gateway Processing Centre
# 88   Business Reply Mail Processing Centre 969 Eastern
# 89        Humber Bay Shores, Mimico South, New Toronto
# 90                              Alderwood, Long Branch
# 91       The Kingsway, Montgomery Road, Old Mill North
# 92   Humber Bay, King's Mill Park, Kingsway Park So...
# 93   Kingsway Park South West, Mimico NW, The Queen...
# 94                                    Islington Avenue
# 95   Cloverdale, Islington, Martin Grove, Princess ...
# 96   Bloordale Gardens, Eringate, Markland Wood, Ol...
# 97                                       Humber Summit
# 98                                    Emery, Humberlea
# 99                                              Weston
# 100                                          Westmount
# 101  Kingsview Village, Martin Grove Gardens, Richv...
# 102  Albion Gardens, Beaumond Heights, Humbergate, ...
# 103                                          Northwest
#
# [104 rows x 3 columns]

# %%
# !pip install geocoder
# Out:
# Collecting geocoder
#   Downloading https://files.pythonhosted.org/packages/4f/6b/13166c909ad2f2d76b929a4227c952630ebaf0d729f6317eb09cbceccbab/geocoder-1.38.1-py2.py3-none-any.whl (98kB)
# Collecting ratelim (from geocoder)
#   Downloading https://files.pythonhosted.org/packages/f2/98/7e6d147fd16a10a5f821db6e25f192265d6ecca3d82957a4fdd592cad49c/ratelim-0.1.6-py2.py3-none-any.whl
# Requirement already satisfied: click in d:\anaconda3\lib\site-packages (from geocoder) (7.0)
# Requirement already satisfied: future in d:\anaconda3\lib\site-packages (from geocoder) (0.17.1)
# Requirement already satisfied: six in d:\anaconda3\lib\site-packages (from geocoder) (1.12.0)
# Requirement already satisfied: requests in d:\anaconda3\lib\site-packages (from geocoder) (2.21.0)
# Requirement already satisfied: decorator in d:\anaconda3\lib\site-packages (from ratelim->geocoder) (4.3.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in d:\anaconda3\lib\site-packages (from requests->geocoder) (1.24.1)
# Requirement already satisfied: idna<2.9,>=2.5 in d:\anaconda3\lib\site-packages (from requests->geocoder) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in d:\anaconda3\lib\site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\lib\site-packages (from requests->geocoder) (2019.6.16)
# Installing collected packages: ratelim, geocoder
# Successfully installed geocoder-1.38.1 ratelim-0.1.6

# %%
import geocoder # import geocoder

# initialize your variable to None
lat_lng_coords = None

# loop until you get the coordinates
while(lat_lng_coords is None):
    g = geocoder.google('{}, Toronto, Ontario'.format(df['PostCode']))
    lat_lng_coords = g.latlng

latitude = lat_lng_coords[0]
longitude = lat_lng_coords[1]
# Out:
# Status code Unknown from https://maps.googleapis.com/maps/api/geocode/json: ERROR - HTTPSConnectionPool(host='maps.googleapis.com', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://maps.googleapis.com/maps/api/geocode/json: ERROR - HTTPSConnectionPool(host='maps.googleapis.com', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://maps.googleapis.com/maps/api/geocode/json: ERROR - HTTPSConnectionPool(host='maps.googleapis.com', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://maps.googleapis.com/maps/api/geocode/json: ERROR - HTTPSConnectionPool(host='maps.googleapis.com', port=443): Max retries exceeded with url: /maps/api/geocode/json?address=0++++++++0%0A1++++++M1B%0A2++++++M1C%0A3++++++M1E%0A4++++++M1G%0A5++++++M1H%0A6++++++M1J%0A7++++++M1K%0A8++++++M1L%0A9++++++M1M%0A10+++++M1N%0A11+++++M1P%0A12+++++M1R%0A13+++++M1S%0A14+++++M1T%0A15+++++M1V%0A16+++++M1W%0A17+++++M1X%0A18+++++M2H%0A19+++++M2J%0A20+++++M2K%0A21+++++M2L%0A22+++++M2M%0A23+++++M2N%0A24+++++M2P%0A25+++++M2R%0A26+++++M3A%0A27+++++M3B%0A28+++++M3C%0A29+++++M3H%0A++++++...+%0A74+++++M6C%0A75+++++M6E%0A76+++++M6G%0A77+++++M6H%0A78+++++M6J%0A79+++++M6K%0A80+++++M6L%0A81+++++M6M%0A82+++++M6N%0A83+++++M6P%0A84+++++M6R%0A85+++++M6S%0A86+++++M7A%0A87+++++M7R%0A88+++++M7Y%0A89+++++M8V%0A90+++++M8W%0A91+++++M8X%0A92+++++M8Y%0A93+++++M8Z%0A94+++++M9A%0A95+++++M9B%0A96+++++M9C%0A97+++++M9L%0A98+++++M9M%0A99+++++M9N%0A100++++M9P%0A101++++M9R%0A102++++M9V%0A103++++M9W%0AName%3A+PostCode%2C+Length%3A+104%2C+dtype%3A+object%2C+Toronto%2C+Ontario&bounds=&components=&region=&language= (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x000000000948B978>, 'Connection to maps.googleapis.com timed out. (connect timeout=5.0)'))
# Status code Unknown from https://maps.googleapis.com/maps/api/geocode/json: ERROR - HTTPSConnectionPool(host='maps.googleapis.com', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://maps.googleapis.com/maps/api/geocode/json: ERROR - HTTPSConnectionPool(host='maps.googleapis.com', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://maps.googleapis.com/maps/api/geocode/json: ERROR - HTTPSConnectionPool(host='maps.googleapis.com', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://maps.googleapis.com/maps/api/geocode/json: ERROR - HTTPSConnectionPool(host='maps.googleapis.com', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://maps.googleapis.com/maps/api/geocode/json: ERROR - HTTPSConnectionPool(host='maps.googleapis.com', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://maps.googleapis.com/maps/api/geocode/json: ERROR - HTTPSConnectionPool(host='maps.googleapis.com', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://maps.googleapis.com/maps/api/geocode/json: ERROR - HTTPSConnectionPool(host='maps.googleapis.com', port=443): Read timed out. (read timeout=5.0)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-bd8ff863a951> in <module>
#       6 # loop until you get the coordinates
#       7 while(lat_lng_coords is None):
# ----> 8     g = geocoder.google('{}, Toronto, Ontario'.format(df['PostCode']))
#       9     lat_lng_coords = g.latlng
#      10
#
# D:\Anaconda3\lib\site-packages\geocoder\api.py in google(location, **kwargs)
#     230         > elevation
#     231     """
# --> 232     return get(location, provider='google', **kwargs)
#     233
#     234
#
# D:\Anaconda3\lib\site-packages\geocoder\api.py in get(location, **kwargs)
#     196         if method not in options[provider]:
#     197             raise ValueError("Invalid method")
# --> 198     return options[provider][method](location, **kwargs)
#     199
#     200
#
# D:\Anaconda3\lib\site-packages\geocoder\base.py in __init__(self, location, **kwargs)
#     408
#     409         # query and parse results
# --> 410         self._initialize()
#     411
#     412     def __getitem__(self, key):
#
# D:\Anaconda3\lib\site-packages\geocoder\base.py in _initialize(self)
#     455     def _initialize(self):
#     456         # query URL and get valid JSON (also stored in self.json)
# --> 457         json_response = self._connect()
#     458
#     459         # catch errors
#
# D:\Anaconda3\lib\site-packages\geocoder\base.py in _connect(self)
#     482                 headers=self.headers,
#     483                 timeout=self.timeout,
# --> 484                 proxies=self.proxies
#     485             )
#     486
#
# D:\Anaconda3\lib\site-packages\geocoder\google.py in rate_limited_get(self, *args, **kwargs)
#     267             return self.rate_limited_get_for_work(*args, **kwargs)
#     268         else:
# --> 269             return self.rate_limited_get_for_dev(*args, **kwargs)
#     270
#     271     @ratelim.greedy(2500, 60 * 60 * 24)
#
# <decorator-gen-128> in rate_limited_get_for_dev(self, *args, **kwargs)
#
# D:\Anaconda3\lib\site-packages\ratelim\__init__.py in wrapped_f(self, f, *args, **kwargs)
#      36
#      37         self.__numcalls += 1
# ---> 38         return f(*args, **kwargs)
#      39
#      40     def __call__(self, f, *args, **kwargs):
#
# <decorator-gen-127> in rate_limited_get_for_dev(self, *args, **kwargs)
#
# D:\Anaconda3\lib\site-packages\ratelim\__init__.py in wrapped_f(self, f, *args, **kwargs)
#      36
#      37         self.__numcalls += 1
# ---> 38         return f(*args, **kwargs)
#      39
#      40     def __call__(self, f, *args, **kwargs):
#
# D:\Anaconda3\lib\site-packages\geocoder\google.py in rate_limited_get_for_dev(self, *args, **kwargs)
#     272     @ratelim.greedy(10, 1)
#     273     def rate_limited_get_for_dev(self, *args, **kwargs):
# --> 274         return super(GoogleQuery, self).rate_limited_get(*args, **kwargs)
#     275
#     276     @ratelim.greedy(100000, 60 * 60 * 24)  # Google for Work daily limit
#
# D:\Anaconda3\lib\site-packages\geocoder\base.py in rate_limited_get(self, url, **kwargs)
#     508     def rate_limited_get(self, url, **kwargs):
#     509         """ By default, simply wraps a session.get request"""
# --> 510         return self.session.get(url, **kwargs)
#     511
#     512     def _adapt_results(self, json_response):
#
# D:\Anaconda3\lib\site-packages\requests\sessions.py in get(self, url, **kwargs)
#     544
#     545         kwargs.setdefault('allow_redirects', True)
# --> 546         return self.request('GET', url, **kwargs)
#     547
#     548     def options(self, url, **kwargs):
#
# D:\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# D:\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# D:\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# D:\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# D:\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     341         # Trigger any extra validation we need to do.
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#     345             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# D:\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     837         # Force connect early to allow us to validate the connection.
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#     841         if not conn.is_verified:
#
# D:\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     330             self.ssl_context = create_urllib3_context(
#     331                 ssl_version=resolve_ssl_version(self.ssl_version),
# --> 332                 cert_reqs=resolve_cert_reqs(self.cert_reqs),
#     333             )
#     334
#
# D:\Anaconda3\lib\site-packages\urllib3\util\ssl_.py in create_urllib3_context(ssl_version, cert_reqs, options, ciphers)
#     262     :rtype: SSLContext
#     263     """
# --> 264     context = SSLContext(ssl_version or ssl.PROTOCOL_SSLv23)
#     265
#     266     context.set_ciphers(ciphers or DEFAULT_CIPHERS)
#
# D:\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in __init__(self, protocol)
#     389     def __init__(self, protocol):
#     390         self.protocol = _openssl_versions[protocol]
# --> 391         self._ctx = OpenSSL.SSL.Context(self.protocol)
#     392         self._options = 0
#     393         self.check_hostname = False
#
# D:\Anaconda3\lib\site-packages\OpenSSL\SSL.py in __init__(self, method)
#     715         _openssl_assert(method_obj != _ffi.NULL)
#     716
# --> 717         context = _lib.SSL_CTX_new(method_obj)
#     718         _openssl_assert(context != _ffi.NULL)
#     719         context = _ffi.gc(context, _lib.SSL_CTX_free)
#
# KeyboardInterrupt:
